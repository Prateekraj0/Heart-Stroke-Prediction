# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, f1_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart.csv')

# %%
import sheryanalysis as sh
sh.analyze(df)
# Out:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# 📏 Shape: (918, 12)
# 🧱 Columns: ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']
#
# ✅ No null values found
#
# 🔠 Categorical Columns: ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'HeartDisease']
#
# 🔢 Numerical Columns: ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
# {'shape': (918, 12),
#  'columns': ['Age',
#   'Sex',
#   'ChestPainType',
#   'RestingBP',
#   'Cholesterol',
#   'FastingBS',
#   'RestingECG',
#   'MaxHR',
#   'ExerciseAngina',
#   'Oldpeak',
#   'ST_Slope',
#   'HeartDisease'],
#  'dtypes': {'Age': dtype('int64'),
#   'Sex': <StringDtype(na_value=nan)>,
#   'ChestPainType': <StringDtype(na_value=nan)>,
#   'RestingBP': dtype('int64'),
#   'Cholesterol': dtype('int64'),
#   'FastingBS': dtype('int64'),
# ...

# %%
df
# Out:
#      Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0     40   M           ATA  ...      0.0        Up             0
# 1     49   F           NAP  ...      1.0      Flat             1
# 2     37   M           ATA  ...      0.0        Up             0
# 3     48   F           ASY  ...      1.5      Flat             1
# 4     54   M           NAP  ...      0.0        Up             0
# ..   ...  ..           ...  ...      ...       ...           ...
# 913   45   M            TA  ...      1.2      Flat             1
# 914   68   M           ASY  ...      3.4      Flat             1
# 915   57   M           ASY  ...      1.2      Flat             1
# 916   57   F           ATA  ...      0.0      Flat             1
# 917   38   M           NAP  ...      0.0        Up             0
#
# [918 rows x 12 columns]

# %%
sns.countplot(x = df['ChestPainType'])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.histplot(x = df['RestingBP'], bins=20)
# Out:
# <Axes: xlabel='RestingBP', ylabel='Count'>

# %%
sns.histplot(x = df['Cholesterol'], bins=20)
# Out:
# <Axes: xlabel='Cholesterol', ylabel='Count'>

# %%
df['FastingBS'].value_counts()
# Out:
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64

# %%
df['RestingECG'].value_counts()
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
df['ST_Slope'].value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
ch_mean = df.loc[df['Cholesterol'] !=0 , 'Cholesterol'].mean()
ch_mean = ch_mean.round(2)

# %%
df['Cholesterol'] = df['Cholesterol'].replace(0,ch_mean)

# %%
res_bp = df.loc[df['RestingBP'] !=0 , 'RestingBP'].mean()
res_bp = res_bp.round(2)
res_bp
# Out:
# np.float64(132.54)

# %%
df['RestingBP'] = df['RestingBP'].replace(0,res_bp)

# %%
plt.subplot(2,2,1)
sns.histplot(x = df['Cholesterol'])

plt.subplot(2,2,2)
sns.histplot(x = df['RestingBP'])
# Out:
# <Axes: xlabel='RestingBP', ylabel='Count'>

# %%
df_encode = pd.get_dummies(df, drop_first=True)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  ...  ExerciseAngina_Y  ST_Slope_Flat  ST_Slope_Up
# 0     40      140.0        289.0  ...             False          False         True
# 1     49      160.0        180.0  ...             False           True        False
# 2     37      130.0        283.0  ...             False          False         True
# 3     48      138.0        214.0  ...              True           True        False
# 4     54      150.0        195.0  ...             False          False         True
# ..   ...        ...          ...  ...               ...            ...          ...
# 913   45      110.0        264.0  ...             False           True        False
# 914   68      144.0        193.0  ...             False           True        False
# 915   57      130.0        131.0  ...              True           True        False
# 916   57      130.0        236.0  ...             False           True        False
# ...

# %%
df_encode = df_encode.astype(int)
df_encode
# Out:
#      Age  RestingBP  Cholesterol  ...  ExerciseAngina_Y  ST_Slope_Flat  ST_Slope_Up
# 0     40        140          289  ...                 0              0            1
# 1     49        160          180  ...                 0              1            0
# 2     37        130          283  ...                 0              0            1
# 3     48        138          214  ...                 1              1            0
# 4     54        150          195  ...                 0              0            1
# ..   ...        ...          ...  ...               ...            ...          ...
# 913   45        110          264  ...                 0              1            0
# 914   68        144          193  ...                 0              1            0
# 915   57        130          131  ...                 1              1            0
# 916   57        130          236  ...                 0              1            0
# ...

# %%
# Here is The main Part where we will apply all the model and they are:
# 1. Logistic Regression
# 2. KNN
# 3. Naive Bayes
# 4. Decision Tree
# 5. SVM

# %%
x = df_encode.drop('HeartDisease', axis = 1)
y = df_encode['HeartDisease']

# %%
# Firstly Train Test and Split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20, random_state=42)

# %%
# Scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

# %%
# 1. Logistic Regression - Feature Scaling Not Needed

# %%
model_LR = LogisticRegression()

# %%
model_LR.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_LR = model_LR.predict(x_test)

# %%
accuracy_score(y_test, y_pred_LR)
# Out:
# 0.8532608695652174

# %%
print(classification_report(y_test, y_pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83        77
#            1       0.90      0.84      0.87       107
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.86      0.85       184
# weighted avg       0.86      0.85      0.85       184

# %%
# 2. KNN - Feature Scaling Needed

# %%
model_KNN = KNeighborsClassifier(n_neighbors=5)

# %%
model_KNN.fit(x_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_KNN = model_KNN.predict(x_test_scaled)

# %%
accuracy_score(y_test ,y_pred_KNN)
# Out:
# 0.8641304347826086

# %%
# 2. Naive Bayes - feature Scaling not Needed

# %%
model_NB = GaussianNB()

# %%
model_NB.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_NB = model_NB.predict(x_test)

# %%
accuracy_score(y_test, y_pred_NB)
# Out:
# 0.8478260869565217

# %%
print(classification_report(y_test, y_pred_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.83        77
#            1       0.92      0.81      0.86       107
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.85      0.85       184
# weighted avg       0.86      0.85      0.85       184

# %%
# 4. Decision Tree

# %%
model_DT = DecisionTreeClassifier(random_state=42)

# %%
model_DT.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_DT = model_DT.predict(x_test_scaled)

# %%
accuracy_score(y_test, y_pred_DT)
# Out:
# 0.782608695652174

# %%
# 5. SVM - Feature Scaling Required

# %%
model_SVM = SVC(kernel = 'rbf')

# %%
model_SVM.fit(x_train_scaled, y_train)
# Out:
# SVC()

# %%
y_pred_SVM = model_SVM.predict(x_test_scaled)

# %%
accuracy_score(y_test, y_pred_SVM)
# Out:
# 0.8478260869565217

# %%
models = {
    "logistic Regression" : LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "Naive Byeas": GaussianNB(),
    "Decision tree": DecisionTreeClassifier(),
    "SVM": SVC()
}

# %%
results = []

# %%
for name,model in models.items():
    model.fit(x_train_scaled, y_train)
    y_pred = model.predict(x_test_scaled)
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results.append({
        "model": name,
        "acc" : acc,
        "f2" : f1
    })

# %%
results
# Out:
# [{'model': 'logistic Regression',
#   'acc': 0.8695652173913043,
#   'f2': 0.8857142857142857},
#  {'model': 'KNN', 'acc': 0.8641304347826086, 'f2': 0.8815165876777251},
#  {'model': 'Naive Byeas', 'acc': 0.8532608695652174, 'f2': 0.8682926829268293},
#  {'model': 'Decision tree',
#   'acc': 0.7663043478260869,
#   'f2': 0.7902439024390244},
#  {'model': 'SVM', 'acc': 0.8478260869565217, 'f2': 0.8679245283018868}]

# %%
import joblib
joblib.dump(models['logistic Regression'], 'Log_Reg_heart.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(x.columns.tolist(), 'columns.pkl')
# Out:
# ['columns.pkl']
